# %%
import pandas as pd
from sklearn import tree
import numpy as np
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV

# %%
d = pd.read_csv("validation/validate.csv")
d.head()
# Out:
#    Unnamed: 0  sound.files  selec  duration  meanfreq        sd  freq.median  \
# 0           1    Bai_1.wav      0         1  1.076572  1.612314     0.558025
# 1           2    Bai_2.wav      0         1  2.025090  2.869171     0.788036
# 2           3    Bai_3.wav      0         1  3.822858  4.172852     1.413064
# 3           4  hello_1.wav      0         1  0.926915  1.144354     0.800036
# 4           5  hello_2.wav      0         1  1.336109  2.046523     0.633029
#
#    freq.Q25  freq.Q75  freq.IQR  ...   meandom    mindom    maxdom   dfrange  \
# 0  0.295013  0.843038  0.548025  ...  0.489391  0.258398  5.598633  5.340234
# 1  0.386018  2.042093  1.656075  ...  0.344531  0.344531  0.344531  0.000000
# 2  0.368017  7.596345  7.228329  ...  0.424922  0.172266  1.378125  1.205859
# 3  0.401018  0.851039  0.450020  ...  0.508758  0.258398  0.861328  0.602930
# 4  0.359016  1.132051  0.773035  ...  0.426026  0.086133  0.775195  0.689063
#
#      modindx  startdom    enddom   dfslope  meanpeakf  class
# 0   2.419355  0.344531  0.344531  0.000000   0.302482    Bai
# 1   1.000000  0.344531  0.344531  0.000000   0.388954    Bai
# 2   2.428571  0.258398  0.602930  0.344531   0.302482    Bai
# 3   2.428571  0.430664  0.516797  0.086133   0.475426  hello
# 4  27.000000  0.689063  0.344531 -0.344531   0.388954  hello
#
# [5 rows x 30 columns]

# %%
y = d["class"].values
print(y)
# Out:
# ['Bai' 'Bai' 'Bai' 'hello' 'hello' 'hello' 'joy' 'joy' 'joy' 'pan' 'pan'
#  'pan' 'Poulami' 'Poulami' 'Poulami' 'pra' 'pra' 'pra' 'so' 'so' 'so']

# %%
clh = tree.DecisionTreeClassifier(max_depth  = 10)
clf = AdaBoostClassifier(base_estimator= clh,n_estimators=10)
clf.fit(d.values, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-f4fed8ef30eb> in <module>
#       1 clh = tree.DecisionTreeClassifier(max_depth  = 10)
#       2 clf = AdaBoostClassifier(base_estimator= clh,n_estimators=10)
# ----> 3 clf.fit(d.values, y)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py in fit(self, X, y, sample_weight)
#     410
#     411         # Fit
# --> 412         return super(AdaBoostClassifier, self).fit(X, y, sample_weight)
#     413
#     414     def _validate_estimator(self):
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py in fit(self, X, y, sample_weight)
#     108
#     109         X, y = check_X_y(X, y, accept_sparse=accept_sparse, dtype=dtype,
# --> 110                          y_numeric=is_regressor(self))
#     111
#     112         if sample_weight is None:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Bai_1.wav'
